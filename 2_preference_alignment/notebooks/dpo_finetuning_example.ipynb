# %% [markdown]
# #### Monday, January 13, 2025
#
# This notbook runs out of CUDA memory when it tries to train the model using the 2070 Super.

# %%
# only target the 4090 ...
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# # Preference Alignment with Direct Preference Optimization (DPO)
#
# This notebook will guide you through the process of fine-tuning a language model using Direct Preference Optimization (DPO). We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; color:black'>
#      <h2 style='margin: 0;color:blue'>Exercise: Aligning SmolLM2 with DPOTrainer</h2>
#      <p>Take a dataset from the Hugging Face hub and align a model on it. </p>
#      <p><b>Difficulty Levels</b></p>
#      <p>🐢 Use the `trl-lib/ultrafeedback_binarized` dataset</p>
#      <p>🐕 Try out the `argilla/ultrafeedback-binarized-preferences` dataset</p>
#      <p>🦁 Select a dataset that relates to a real-world use case you’re interested in, or use the model you trained in
#         <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# Install the requirements in Google Colab
# !pip install transformers datasets trl huggingface_hub

# Authenticate to Hugging Face

from huggingface_hub import login

login()

# for convenience you can create an environment variable containing your hub token as HF_TOKEN
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Token has not been saved to git credential helper.

# %% [markdown]
# ## Import libraries

# %%
import torch
import os
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset
from trl import DPOTrainer, DPOConfig

# %% [markdown]
# ## Format dataset

# %%
# Load dataset

# TODO: 🦁🐕 change the dataset to one of your choosing
dataset = load_dataset(path="trl-lib/ultrafeedback_binarized", split="train")

# %%
# TODO: 🐕 If your dataset is not represented as conversation lists, you can use the `process_dataset` function to convert it.

# %% [markdown]
# ## Select the model
#
# We will use the SmolLM2-135M-Instruct model which has already been through a SFT training, so it it compatible with DPO. You can also use the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb).
#
#
# <div style='background-color: lightblue; padding: 10px; border-radius: 5px; margin-bottom: 20px; width:80%; color:black'>
#      <p>🦁 change the model to the path or repo id of the model you trained in <a href="../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb">1_instruction_tuning</a></p>
# </div>

# %%
# TODO: 🦁 change the model to the path or repo id of the model you trained in [1_instruction_tuning](../../1_instruction_tuning/notebooks/sft_finetuning_example.ipynb)

model_name = "HuggingFaceTB/SmolLM2-135M-Instruct"

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)
device
# Out:
# 'cuda'

# %%
# Model to fine-tune
model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=model_name,
    torch_dtype=torch.float32,
).to(device)
model.config.use_cache = False
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# %%
# Set our name for the finetune to be saved &/ uploaded to
finetune_name = "SmolLM2-FT-DPO"
finetune_tags = ["smol-course", "module_1"]

# %% [markdown]
# ## Train model with DPO

# %%
# Training arguments
training_args = DPOConfig(
    # Training batch size per GPU
    per_device_train_batch_size=4,
    # Number of updates steps to accumulate before performing a backward/update pass
    # Effective batch size = per_device_train_batch_size * gradient_accumulation_steps
    gradient_accumulation_steps=4,
    # Saves memory by not storing activations during forward pass
    # Instead recomputes them during backward pass
    gradient_checkpointing=True,
    # Base learning rate for training
    learning_rate=5e-5,
    # Learning rate schedule - 'cosine' gradually decreases LR following cosine curve
    lr_scheduler_type="cosine",
    # Total number of training steps
    max_steps=200,
    # Disables model checkpointing during training
    save_strategy="no",
    # How often to log training metrics
    logging_steps=1,
    # Directory to save model outputs
    output_dir="smol_dpo_output",
    # Number of steps for learning rate warmup
    warmup_steps=100,
    # Use bfloat16 precision for faster training
    bf16=True,
    # Disable wandb/tensorboard logging
    report_to="none",
    # Keep all columns in dataset even if not used
    remove_unused_columns=False,
    # Enable MPS (Metal Performance Shaders) for Mac devices
    use_mps_device=device == "mps",
    # Model ID for HuggingFace Hub uploads
    hub_model_id=finetune_name,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    beta=0.1,
    # Maximum length of the input prompt in tokens
    max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    max_length=1536,
)

# %%
# this does not use the GPU
trainer = DPOTrainer(
    # The model to be trained
    model=model,
    # Training configuration from above
    args=training_args,
    # Dataset containing preferred/rejected response pairs
    train_dataset=dataset,
    # Tokenizer for processing inputs
    processing_class=tokenizer,
    # DPO-specific temperature parameter that controls the strength of the preference model
    # Lower values (like 0.1) make the model more conservative in following preferences
    # beta=0.1,
    # Maximum length of the input prompt in tokens
    # max_prompt_length=1024,
    # Maximum combined length of prompt + response in tokens
    # max_length=1536,
)

# 1m 59.3s on KAUWITB 

# 1m 33.3s on the Kitchen computer
# Out:
# max_steps is given, it will override any value given in num_train_epochs

# %%
# Train the model
trainer.train()

# 3m 32.9s on the 4090 ... 15996Mib
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# /home/rob/Data/Documents/Github/rkaunismaa/smol-course/.venv/lib/python3.11/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 0.6931, 'grad_norm': 80.04003143310547, 'learning_rate': 5.000000000000001e-07, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -453.27880859375, 'logps/rejected': -332.2112731933594, 'logits/chosen': 4.74647855758667, 'logits/rejected': 4.018367290496826, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 84.17562103271484, 'learning_rate': 1.0000000000000002e-06, 'rewards/chosen': 0.0, 'rewards/rejected': 0.0, 'rewards/accuracies': 0.0, 'rewards/margins': 0.0, 'logps/chosen': -448.5394287109375, 'logps/rejected': -387.55694580078125, 'logits/chosen': 4.018608093261719, 'logits/rejected': 5.054816722869873, 'epoch': 0.0}
# {'loss': 0.6829, 'grad_norm': 91.43978881835938, 'learning_rate': 1.5e-06, 'rewards/chosen': 0.022497734054923058, 'rewards/rejected': -0.0018811225891113281, 'rewards/accuracies': 0.625, 'rewards/margins': 0.024378858506679535, 'logps/chosen': -632.2772827148438, 'logps/rejected': -477.2018127441406, 'logits/chosen': 3.6871652603149414, 'logits/rejected': 4.154798984527588, 'epoch': 0.0}
# {'loss': 0.6875, 'grad_norm': 63.13433837890625, 'learning_rate': 2.0000000000000003e-06, 'rewards/chosen': 0.012081574648618698, 'rewards/rejected': -0.0003982067573815584, 'rewards/accuracies': 0.5, 'rewards/margins': 0.012479781173169613, 'logps/chosen': -265.0361022949219, 'logps/rejected': -271.5714111328125, 'logits/chosen': 4.101006507873535, 'logits/rejected': 4.154720306396484, 'epoch': 0.0}
# {'loss': 0.7034, 'grad_norm': 70.31724548339844, 'learning_rate': 2.5e-06, 'rewards/chosen': -0.030070777982473373, 'rewards/rejected': -0.011668790131807327, 'rewards/accuracies': 0.5, 'rewards/margins': -0.018401989713311195, 'logps/chosen': -311.5815734863281, 'logps/rejected': -255.83489990234375, 'logits/chosen': 3.2214248180389404, 'logits/rejected': 3.8082187175750732, 'epoch': 0.0}
# {'loss': 0.7025, 'grad_norm': 64.193359375, 'learning_rate': 3e-06, 'rewards/chosen': -0.01019587554037571, 'rewards/rejected': 0.006381977815181017, 'rewards/accuracies': 0.375, 'rewards/margins': -0.01657785102725029, 'logps/chosen': -295.08648681640625, 'logps/rejected': -221.89459228515625, 'logits/chosen': 3.9702632427215576, 'logits/rejected': 4.852461338043213, 'epoch': 0.0}
# {'loss': 0.6957, 'grad_norm': 96.78465270996094, 'learning_rate': 3.5000000000000004e-06, 'rewards/chosen': -0.0024381522089242935, 'rewards/rejected': 0.00016381219029426575, 'rewards/accuracies': 0.5, 'rewards/margins': -0.0026019643992185593, 'logps/chosen': -544.6516723632812, 'logps/rejected': -305.91717529296875, 'logits/chosen': 3.7277045249938965, 'logits/rejected': 2.6390209197998047, 'epoch': 0.0}
# {'loss': 0.7046, 'grad_norm': 81.979248046875, 'learning_rate': 4.000000000000001e-06, 'rewards/chosen': -0.009140826761722565, 'rewards/rejected': 0.011390818282961845, 'rewards/accuracies': 0.5, 'rewards/margins': -0.02053164318203926, 'logps/chosen': -454.5331115722656, 'logps/rejected': -346.8436279296875, 'logits/chosen': 3.371677875518799, 'logits/rejected': 4.417679309844971, 'epoch': 0.0}
# {'loss': 0.6931, 'grad_norm': 85.00667572021484, 'learning_rate': 4.5e-06, 'rewards/chosen': 0.011688866652548313, 'rewards/rejected': 0.009346570819616318, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.00234229676425457, 'logps/chosen': -417.84368896484375, 'logps/rejected': -418.20458984375, 'logits/chosen': 3.5065407752990723, 'logits/rejected': 3.441415309906006, 'epoch': 0.0}
# {'loss': 0.684, 'grad_norm': 70.21924591064453, 'learning_rate': 5e-06, 'rewards/chosen': 0.01277459878474474, 'rewards/rejected': -0.006435060873627663, 'rewards/accuracies': 0.5, 'rewards/margins': 0.019209660589694977, 'logps/chosen': -276.2864685058594, 'logps/rejected': -340.598876953125, 'logits/chosen': 4.396976470947266, 'logits/rejected': 4.053260803222656, 'epoch': 0.0}
# {'loss': 0.6938, 'grad_norm': 79.6173095703125, 'learning_rate': 5.500000000000001e-06, 'rewards/chosen': 0.0037952661514282227, 'rewards/rejected': 0.001979514490813017, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.001815752126276493, 'logps/chosen': -407.8843994140625, 'logps/rejected': -340.8759460449219, 'logits/chosen': 3.9469804763793945, 'logits/rejected': 4.1842851638793945, 'epoch': 0.0}
# {'loss': 0.6909, 'grad_norm': 92.53311920166016, 'learning_rate': 6e-06, 'rewards/chosen': 0.00974651426076889, 'rewards/rejected': 0.0009071906097233295, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.008839324116706848, 'logps/chosen': -450.8773193359375, 'logps/rejected': -506.99169921875, 'logits/chosen': 2.7423062324523926, 'logits/rejected': 4.098450183868408, 'epoch': 0.0}
# {'loss': 0.7015, 'grad_norm': 95.23619842529297, 'learning_rate': 6.5000000000000004e-06, 'rewards/chosen': -0.01709807477891445, 'rewards/rejected': -0.001777576981112361, 'rewards/accuracies': 0.5, 'rewards/margins': -0.015320498496294022, 'logps/chosen': -489.2403564453125, 'logps/rejected': -449.22296142578125, 'logits/chosen': 5.25901985168457, 'logits/rejected': 4.22179651260376, 'epoch': 0.0}
# {'loss': 0.6899, 'grad_norm': 77.63037109375, 'learning_rate': 7.000000000000001e-06, 'rewards/chosen': 0.015363524667918682, 'rewards/rejected': 0.007011711597442627, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.008351811207830906, 'logps/chosen': -357.3983154296875, 'logps/rejected': -284.46514892578125, 'logits/chosen': 3.084414482116699, 'logits/rejected': 4.444788455963135, 'epoch': 0.0}
# {'loss': 0.7082, 'grad_norm': 77.1403579711914, 'learning_rate': 7.5e-06, 'rewards/chosen': -0.020647168159484863, 'rewards/rejected': 0.0053626238368451595, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.02600979059934616, 'logps/chosen': -409.7562255859375, 'logps/rejected': -320.7686462402344, 'logits/chosen': 2.4405417442321777, 'logits/rejected': 2.6486141681671143, 'epoch': 0.0}
# {'loss': 0.6883, 'grad_norm': 90.00883483886719, 'learning_rate': 8.000000000000001e-06, 'rewards/chosen': -0.012188469991087914, 'rewards/rejected': -0.024546420201659203, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.012357950210571289, 'logps/chosen': -455.12896728515625, 'logps/rejected': -341.0699462890625, 'logits/chosen': 4.708561420440674, 'logits/rejected': 4.084074020385742, 'epoch': 0.0}
# {'loss': 0.714, 'grad_norm': 80.80046081542969, 'learning_rate': 8.500000000000002e-06, 'rewards/chosen': -0.008290196768939495, 'rewards/rejected': 0.03220890089869499, 'rewards/accuracies': 0.3125, 'rewards/margins': -0.04049909859895706, 'logps/chosen': -441.17218017578125, 'logps/rejected': -390.8725891113281, 'logits/chosen': 1.9858406782150269, 'logits/rejected': 2.714627265930176, 'epoch': 0.0}
# {'loss': 0.6825, 'grad_norm': 78.32166290283203, 'learning_rate': 9e-06, 'rewards/chosen': 0.012772567570209503, 'rewards/rejected': -0.011524772271513939, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.02429734356701374, 'logps/chosen': -461.4307861328125, 'logps/rejected': -328.87713623046875, 'logits/chosen': 2.8636581897735596, 'logits/rejected': 2.855545997619629, 'epoch': 0.0}
# {'loss': 0.6891, 'grad_norm': 80.17486572265625, 'learning_rate': 9.5e-06, 'rewards/chosen': -0.00690800417214632, 'rewards/rejected': -0.018580423668026924, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.011672420427203178, 'logps/chosen': -413.3273010253906, 'logps/rejected': -341.9375, 'logits/chosen': 3.4086790084838867, 'logits/rejected': 3.664458751678467, 'epoch': 0.0}
# {'loss': 0.6814, 'grad_norm': 70.42308807373047, 'learning_rate': 1e-05, 'rewards/chosen': -0.006719675846397877, 'rewards/rejected': -0.03167548403143883, 'rewards/accuracies': 0.625, 'rewards/margins': 0.024955805391073227, 'logps/chosen': -355.16131591796875, 'logps/rejected': -291.2333984375, 'logits/chosen': 3.429685592651367, 'logits/rejected': 3.896235704421997, 'epoch': 0.01}
# {'loss': 0.6976, 'grad_norm': 78.03308868408203, 'learning_rate': 1.05e-05, 'rewards/chosen': -0.02355017699301243, 'rewards/rejected': -0.016104042530059814, 'rewards/accuracies': 0.3125, 'rewards/margins': -0.00744613679125905, 'logps/chosen': -436.39739990234375, 'logps/rejected': -373.94293212890625, 'logits/chosen': 4.3479156494140625, 'logits/rejected': 4.12689733505249, 'epoch': 0.01}
# {'loss': 0.7039, 'grad_norm': 82.82032012939453, 'learning_rate': 1.1000000000000001e-05, 'rewards/chosen': -0.029417891055345535, 'rewards/rejected': -0.010688945651054382, 'rewards/accuracies': 0.3125, 'rewards/margins': -0.018728947266936302, 'logps/chosen': -483.3346252441406, 'logps/rejected': -401.0805358886719, 'logits/chosen': 4.465714454650879, 'logits/rejected': 3.8177907466888428, 'epoch': 0.01}
# {'loss': 0.6866, 'grad_norm': 68.32624816894531, 'learning_rate': 1.1500000000000002e-05, 'rewards/chosen': 0.004785391502082348, 'rewards/rejected': -0.009433364495635033, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.01421875599771738, 'logps/chosen': -249.55972290039062, 'logps/rejected': -277.9830627441406, 'logits/chosen': 3.673149824142456, 'logits/rejected': 4.193233013153076, 'epoch': 0.01}
# {'loss': 0.6605, 'grad_norm': 72.14262390136719, 'learning_rate': 1.2e-05, 'rewards/chosen': 0.019950373098254204, 'rewards/rejected': -0.05061635002493858, 'rewards/accuracies': 0.625, 'rewards/margins': 0.07056672871112823, 'logps/chosen': -459.32232666015625, 'logps/rejected': -417.76959228515625, 'logits/chosen': 3.196542263031006, 'logits/rejected': 3.128146171569824, 'epoch': 0.01}
# {'loss': 0.6893, 'grad_norm': 66.4658203125, 'learning_rate': 1.25e-05, 'rewards/chosen': -0.021951252594590187, 'rewards/rejected': -0.03181992843747139, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.009868675842881203, 'logps/chosen': -427.42724609375, 'logps/rejected': -236.8574676513672, 'logits/chosen': 3.045203447341919, 'logits/rejected': 3.014291524887085, 'epoch': 0.01}
# {'loss': 0.6741, 'grad_norm': 70.10480499267578, 'learning_rate': 1.3000000000000001e-05, 'rewards/chosen': 0.006419054698199034, 'rewards/rejected': -0.03346884250640869, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.039887893944978714, 'logps/chosen': -328.9795837402344, 'logps/rejected': -223.14141845703125, 'logits/chosen': 4.337161064147949, 'logits/rejected': 3.9744505882263184, 'epoch': 0.01}
# {'loss': 0.691, 'grad_norm': 77.35612487792969, 'learning_rate': 1.3500000000000001e-05, 'rewards/chosen': -0.010353565216064453, 'rewards/rejected': -0.020303167402744293, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.00994960218667984, 'logps/chosen': -344.21942138671875, 'logps/rejected': -303.77752685546875, 'logits/chosen': 4.191852569580078, 'logits/rejected': 4.36151123046875, 'epoch': 0.01}
# {'loss': 0.6811, 'grad_norm': 76.21822357177734, 'learning_rate': 1.4000000000000001e-05, 'rewards/chosen': -0.017056385055184364, 'rewards/rejected': -0.04851861298084259, 'rewards/accuracies': 0.5, 'rewards/margins': 0.03146222606301308, 'logps/chosen': -313.22998046875, 'logps/rejected': -426.2373962402344, 'logits/chosen': 2.8000478744506836, 'logits/rejected': 3.828367233276367, 'epoch': 0.01}
# {'loss': 0.7202, 'grad_norm': 101.28416442871094, 'learning_rate': 1.45e-05, 'rewards/chosen': -0.060153767466545105, 'rewards/rejected': -0.010768722742795944, 'rewards/accuracies': 0.3125, 'rewards/margins': -0.049385055899620056, 'logps/chosen': -580.87158203125, 'logps/rejected': -480.3347473144531, 'logits/chosen': 3.3644165992736816, 'logits/rejected': 2.9078447818756104, 'epoch': 0.01}
# {'loss': 0.6567, 'grad_norm': 61.57979202270508, 'learning_rate': 1.5e-05, 'rewards/chosen': 0.0031850093510001898, 'rewards/rejected': -0.07403978705406189, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.07722479104995728, 'logps/chosen': -322.629150390625, 'logps/rejected': -243.26895141601562, 'logits/chosen': 3.2336246967315674, 'logits/rejected': 2.6456410884857178, 'epoch': 0.01}
# {'loss': 0.6896, 'grad_norm': 90.29471588134766, 'learning_rate': 1.55e-05, 'rewards/chosen': -0.03458380699157715, 'rewards/rejected': -0.04622692987322807, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.011643124744296074, 'logps/chosen': -512.9033203125, 'logps/rejected': -427.17486572265625, 'logits/chosen': 4.620770454406738, 'logits/rejected': 3.901634693145752, 'epoch': 0.01}
# {'loss': 0.6736, 'grad_norm': 59.56652069091797, 'learning_rate': 1.6000000000000003e-05, 'rewards/chosen': -0.014973221346735954, 'rewards/rejected': -0.0558110810816288, 'rewards/accuracies': 0.75, 'rewards/margins': 0.040837861597537994, 'logps/chosen': -248.89288330078125, 'logps/rejected': -187.31536865234375, 'logits/chosen': 4.368704795837402, 'logits/rejected': 4.38277530670166, 'epoch': 0.01}
# {'loss': 0.6756, 'grad_norm': 67.33399200439453, 'learning_rate': 1.65e-05, 'rewards/chosen': -0.026535753160715103, 'rewards/rejected': -0.06524104624986649, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.03870529681444168, 'logps/chosen': -293.5777893066406, 'logps/rejected': -264.22113037109375, 'logits/chosen': 3.111060857772827, 'logits/rejected': 4.744899749755859, 'epoch': 0.01}
# {'loss': 0.7012, 'grad_norm': 77.2193374633789, 'learning_rate': 1.7000000000000003e-05, 'rewards/chosen': -0.0644800215959549, 'rewards/rejected': -0.05101565271615982, 'rewards/accuracies': 0.375, 'rewards/margins': -0.013464367017149925, 'logps/chosen': -473.46466064453125, 'logps/rejected': -397.9166259765625, 'logits/chosen': 3.2250261306762695, 'logits/rejected': 2.6748783588409424, 'epoch': 0.01}
# {'loss': 0.688, 'grad_norm': 65.96257019042969, 'learning_rate': 1.75e-05, 'rewards/chosen': -0.043953437358140945, 'rewards/rejected': -0.05600569024682045, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.012052256613969803, 'logps/chosen': -301.1468505859375, 'logps/rejected': -291.7505798339844, 'logits/chosen': 2.5804474353790283, 'logits/rejected': 2.519186496734619, 'epoch': 0.01}
# {'loss': 0.6438, 'grad_norm': 76.05924224853516, 'learning_rate': 1.8e-05, 'rewards/chosen': -0.036566250026226044, 'rewards/rejected': -0.15060211718082428, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11403586715459824, 'logps/chosen': -494.5499267578125, 'logps/rejected': -304.4845275878906, 'logits/chosen': 3.427654981613159, 'logits/rejected': 3.9906415939331055, 'epoch': 0.01}
# {'loss': 0.7004, 'grad_norm': 85.56757354736328, 'learning_rate': 1.85e-05, 'rewards/chosen': -0.062152303755283356, 'rewards/rejected': -0.05192091315984726, 'rewards/accuracies': 0.375, 'rewards/margins': -0.010231387801468372, 'logps/chosen': -445.8209533691406, 'logps/rejected': -435.19036865234375, 'logits/chosen': 3.3391191959381104, 'logits/rejected': 2.8696351051330566, 'epoch': 0.01}
# {'loss': 0.6656, 'grad_norm': 73.66983795166016, 'learning_rate': 1.9e-05, 'rewards/chosen': -0.021612679585814476, 'rewards/rejected': -0.093828946352005, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.07221625745296478, 'logps/chosen': -325.66741943359375, 'logps/rejected': -372.17987060546875, 'logits/chosen': 3.6595396995544434, 'logits/rejected': 4.384152412414551, 'epoch': 0.01}
# {'loss': 0.6701, 'grad_norm': 90.50054168701172, 'learning_rate': 1.9500000000000003e-05, 'rewards/chosen': -0.012402446940541267, 'rewards/rejected': -0.06609812378883362, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.0536956824362278, 'logps/chosen': -629.939697265625, 'logps/rejected': -453.3328857421875, 'logits/chosen': 3.6005442142486572, 'logits/rejected': 3.0379858016967773, 'epoch': 0.01}
# {'loss': 0.6829, 'grad_norm': 69.84042358398438, 'learning_rate': 2e-05, 'rewards/chosen': -0.07234467566013336, 'rewards/rejected': -0.10625788569450378, 'rewards/accuracies': 0.625, 'rewards/margins': 0.033913202583789825, 'logps/chosen': -316.6865234375, 'logps/rejected': -368.6960144042969, 'logits/chosen': 3.6685631275177, 'logits/rejected': 4.319109916687012, 'epoch': 0.01}
# {'loss': 0.6654, 'grad_norm': 74.83468627929688, 'learning_rate': 2.05e-05, 'rewards/chosen': -0.03506898880004883, 'rewards/rejected': -0.10169833153486252, 'rewards/accuracies': 0.625, 'rewards/margins': 0.06662934273481369, 'logps/chosen': -504.80633544921875, 'logps/rejected': -370.304443359375, 'logits/chosen': 3.2154159545898438, 'logits/rejected': 3.998034954071045, 'epoch': 0.01}
# {'loss': 0.7195, 'grad_norm': 87.44941711425781, 'learning_rate': 2.1e-05, 'rewards/chosen': -0.11310671269893646, 'rewards/rejected': -0.07858841121196747, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.03451831266283989, 'logps/chosen': -388.54852294921875, 'logps/rejected': -407.8140563964844, 'logits/chosen': 4.781581878662109, 'logits/rejected': 4.02789831161499, 'epoch': 0.01}
# {'loss': 0.6317, 'grad_norm': 84.78965759277344, 'learning_rate': 2.15e-05, 'rewards/chosen': -0.05519614368677139, 'rewards/rejected': -0.2069379687309265, 'rewards/accuracies': 0.625, 'rewards/margins': 0.1517418473958969, 'logps/chosen': -527.1904296875, 'logps/rejected': -455.17828369140625, 'logits/chosen': 2.741987466812134, 'logits/rejected': 3.8785197734832764, 'epoch': 0.01}
# {'loss': 0.7256, 'grad_norm': 68.028564453125, 'learning_rate': 2.2000000000000003e-05, 'rewards/chosen': -0.13652540743350983, 'rewards/rejected': -0.08923118561506271, 'rewards/accuracies': 0.5, 'rewards/margins': -0.04729422926902771, 'logps/chosen': -253.07090759277344, 'logps/rejected': -242.53741455078125, 'logits/chosen': 4.580117702484131, 'logits/rejected': 3.745795249938965, 'epoch': 0.01}
# {'loss': 0.6237, 'grad_norm': 81.13925170898438, 'learning_rate': 2.25e-05, 'rewards/chosen': 0.017522528767585754, 'rewards/rejected': -0.13942421972751617, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.15694673359394073, 'logps/chosen': -637.0439453125, 'logps/rejected': -426.1091613769531, 'logits/chosen': 3.3391222953796387, 'logits/rejected': 3.561446189880371, 'epoch': 0.01}
# {'loss': 0.6257, 'grad_norm': 76.30374145507812, 'learning_rate': 2.3000000000000003e-05, 'rewards/chosen': 0.0023685339838266373, 'rewards/rejected': -0.17028306424617767, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.17265158891677856, 'logps/chosen': -471.9671325683594, 'logps/rejected': -334.90301513671875, 'logits/chosen': 2.909945249557495, 'logits/rejected': 1.8674118518829346, 'epoch': 0.01}
# {'loss': 0.6575, 'grad_norm': 72.3421401977539, 'learning_rate': 2.35e-05, 'rewards/chosen': -0.0994780957698822, 'rewards/rejected': -0.203098326921463, 'rewards/accuracies': 0.5, 'rewards/margins': 0.10362022370100021, 'logps/chosen': -396.16668701171875, 'logps/rejected': -399.78369140625, 'logits/chosen': 3.7438442707061768, 'logits/rejected': 3.687347173690796, 'epoch': 0.01}
# {'loss': 0.6336, 'grad_norm': 67.98113250732422, 'learning_rate': 2.4e-05, 'rewards/chosen': -0.003736182115972042, 'rewards/rejected': -0.13915769755840302, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1354215145111084, 'logps/chosen': -375.0023193359375, 'logps/rejected': -263.0456848144531, 'logits/chosen': 4.82613468170166, 'logits/rejected': 4.800394535064697, 'epoch': 0.01}
# {'loss': 0.6132, 'grad_norm': 74.66246795654297, 'learning_rate': 2.45e-05, 'rewards/chosen': -0.08827004581689835, 'rewards/rejected': -0.32699793577194214, 'rewards/accuracies': 0.625, 'rewards/margins': 0.238727867603302, 'logps/chosen': -565.76025390625, 'logps/rejected': -491.1802062988281, 'logits/chosen': 3.6125688552856445, 'logits/rejected': 4.11231803894043, 'epoch': 0.01}
# {'loss': 0.5899, 'grad_norm': 66.63826751708984, 'learning_rate': 2.5e-05, 'rewards/chosen': 0.012062912806868553, 'rewards/rejected': -0.23034384846687317, 'rewards/accuracies': 0.875, 'rewards/margins': 0.24240678548812866, 'logps/chosen': -388.19415283203125, 'logps/rejected': -360.0887451171875, 'logits/chosen': 3.85795259475708, 'logits/rejected': 4.135985851287842, 'epoch': 0.01}
# {'loss': 0.6405, 'grad_norm': 69.27156066894531, 'learning_rate': 2.5500000000000003e-05, 'rewards/chosen': -0.09055161476135254, 'rewards/rejected': -0.2126425802707672, 'rewards/accuracies': 0.75, 'rewards/margins': 0.12209095805883408, 'logps/chosen': -381.90960693359375, 'logps/rejected': -315.48394775390625, 'logits/chosen': 2.1179633140563965, 'logits/rejected': 2.088616371154785, 'epoch': 0.01}
# {'loss': 0.6988, 'grad_norm': 72.33301544189453, 'learning_rate': 2.6000000000000002e-05, 'rewards/chosen': -0.08682148158550262, 'rewards/rejected': -0.11120539158582687, 'rewards/accuracies': 0.5, 'rewards/margins': 0.024383895099163055, 'logps/chosen': -433.9724426269531, 'logps/rejected': -331.16650390625, 'logits/chosen': 3.5202603340148926, 'logits/rejected': 3.1957085132598877, 'epoch': 0.01}
# {'loss': 0.7253, 'grad_norm': 88.8133773803711, 'learning_rate': 2.6500000000000004e-05, 'rewards/chosen': -0.11342737823724747, 'rewards/rejected': -0.10711069405078888, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.006316687911748886, 'logps/chosen': -388.1121520996094, 'logps/rejected': -443.3948059082031, 'logits/chosen': 3.028299331665039, 'logits/rejected': 3.7945780754089355, 'epoch': 0.01}
# {'loss': 0.7498, 'grad_norm': 82.89221954345703, 'learning_rate': 2.7000000000000002e-05, 'rewards/chosen': -0.3559769093990326, 'rewards/rejected': -0.2997899651527405, 'rewards/accuracies': 0.625, 'rewards/margins': -0.05618695169687271, 'logps/chosen': -410.85357666015625, 'logps/rejected': -297.9757995605469, 'logits/chosen': 3.2486519813537598, 'logits/rejected': 4.179050445556641, 'epoch': 0.01}
# {'loss': 0.7957, 'grad_norm': 122.30320739746094, 'learning_rate': 2.7500000000000004e-05, 'rewards/chosen': -0.3204880654811859, 'rewards/rejected': -0.23765146732330322, 'rewards/accuracies': 0.375, 'rewards/margins': -0.0828365832567215, 'logps/chosen': -519.96630859375, 'logps/rejected': -470.19940185546875, 'logits/chosen': 4.117985725402832, 'logits/rejected': 5.238395690917969, 'epoch': 0.01}
# {'loss': 0.7305, 'grad_norm': 83.9180679321289, 'learning_rate': 2.8000000000000003e-05, 'rewards/chosen': -0.08799614757299423, 'rewards/rejected': -0.09115919470787048, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.0031630396842956543, 'logps/chosen': -324.42681884765625, 'logps/rejected': -275.4654541015625, 'logits/chosen': 4.0591816902160645, 'logits/rejected': 4.53560209274292, 'epoch': 0.01}
# {'loss': 0.558, 'grad_norm': 66.90782165527344, 'learning_rate': 2.8499999999999998e-05, 'rewards/chosen': -0.09454894065856934, 'rewards/rejected': -0.47622740268707275, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.3816784620285034, 'logps/chosen': -282.1551513671875, 'logps/rejected': -426.6071472167969, 'logits/chosen': 4.582827568054199, 'logits/rejected': 3.8915319442749023, 'epoch': 0.01}
# {'loss': 0.5914, 'grad_norm': 66.95348358154297, 'learning_rate': 2.9e-05, 'rewards/chosen': -0.0761258453130722, 'rewards/rejected': -0.32730042934417725, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.25117459893226624, 'logps/chosen': -443.5160827636719, 'logps/rejected': -263.02227783203125, 'logits/chosen': 3.5182766914367676, 'logits/rejected': 2.9673590660095215, 'epoch': 0.01}
# {'loss': 0.7147, 'grad_norm': 71.94937133789062, 'learning_rate': 2.95e-05, 'rewards/chosen': -0.30669739842414856, 'rewards/rejected': -0.30367130041122437, 'rewards/accuracies': 0.375, 'rewards/margins': -0.0030260831117630005, 'logps/chosen': -374.74334716796875, 'logps/rejected': -389.4515380859375, 'logits/chosen': 3.5098395347595215, 'logits/rejected': 3.29849910736084, 'epoch': 0.02}
# {'loss': 0.651, 'grad_norm': 70.49176025390625, 'learning_rate': 3e-05, 'rewards/chosen': -0.30662107467651367, 'rewards/rejected': -0.4595111310482025, 'rewards/accuracies': 0.75, 'rewards/margins': 0.15289005637168884, 'logps/chosen': -373.35565185546875, 'logps/rejected': -296.0950927734375, 'logits/chosen': 3.668025493621826, 'logits/rejected': 3.7233352661132812, 'epoch': 0.02}
# {'loss': 0.6129, 'grad_norm': 63.27773666381836, 'learning_rate': 3.05e-05, 'rewards/chosen': -0.12204678356647491, 'rewards/rejected': -0.3671606481075287, 'rewards/accuracies': 0.625, 'rewards/margins': 0.24511384963989258, 'logps/chosen': -340.2120361328125, 'logps/rejected': -306.124755859375, 'logits/chosen': 2.867011070251465, 'logits/rejected': 2.66475248336792, 'epoch': 0.02}
# {'loss': 0.7251, 'grad_norm': 74.15432739257812, 'learning_rate': 3.1e-05, 'rewards/chosen': -0.2080521434545517, 'rewards/rejected': -0.2457430064678192, 'rewards/accuracies': 0.375, 'rewards/margins': 0.037690866738557816, 'logps/chosen': -442.5247802734375, 'logps/rejected': -316.0314636230469, 'logits/chosen': 4.37828254699707, 'logits/rejected': 3.706106424331665, 'epoch': 0.02}
# {'loss': 0.6686, 'grad_norm': 102.3222427368164, 'learning_rate': 3.15e-05, 'rewards/chosen': -0.4234236478805542, 'rewards/rejected': -0.6184607148170471, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.19503705203533173, 'logps/chosen': -492.554443359375, 'logps/rejected': -355.89697265625, 'logits/chosen': 3.0435123443603516, 'logits/rejected': 3.2993249893188477, 'epoch': 0.02}
# {'loss': 0.6095, 'grad_norm': 79.32618713378906, 'learning_rate': 3.2000000000000005e-05, 'rewards/chosen': -0.14132213592529297, 'rewards/rejected': -0.3505494296550751, 'rewards/accuracies': 0.75, 'rewards/margins': 0.2092273086309433, 'logps/chosen': -435.57861328125, 'logps/rejected': -384.06207275390625, 'logits/chosen': 3.791219711303711, 'logits/rejected': 3.880082845687866, 'epoch': 0.02}
# {'loss': 0.7819, 'grad_norm': 78.86224365234375, 'learning_rate': 3.2500000000000004e-05, 'rewards/chosen': -0.26240819692611694, 'rewards/rejected': -0.16926492750644684, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.0931432768702507, 'logps/chosen': -254.40325927734375, 'logps/rejected': -325.1853942871094, 'logits/chosen': 3.0479981899261475, 'logits/rejected': 2.9249472618103027, 'epoch': 0.02}
# {'loss': 0.6895, 'grad_norm': 72.63631439208984, 'learning_rate': 3.3e-05, 'rewards/chosen': -0.37785348296165466, 'rewards/rejected': -0.42114701867103577, 'rewards/accuracies': 0.5, 'rewards/margins': 0.04329352080821991, 'logps/chosen': -354.610595703125, 'logps/rejected': -213.06907653808594, 'logits/chosen': 3.58424711227417, 'logits/rejected': 3.4637513160705566, 'epoch': 0.02}
# {'loss': 0.5854, 'grad_norm': 76.6996078491211, 'learning_rate': 3.35e-05, 'rewards/chosen': -0.32686764001846313, 'rewards/rejected': -0.6243609189987183, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.2974932789802551, 'logps/chosen': -520.5267944335938, 'logps/rejected': -403.96600341796875, 'logits/chosen': 3.685368061065674, 'logits/rejected': 3.2923147678375244, 'epoch': 0.02}
# {'loss': 0.703, 'grad_norm': 93.20160675048828, 'learning_rate': 3.4000000000000007e-05, 'rewards/chosen': -0.3445495665073395, 'rewards/rejected': -0.36816301941871643, 'rewards/accuracies': 0.5, 'rewards/margins': 0.02361343242228031, 'logps/chosen': -522.6826782226562, 'logps/rejected': -444.8636169433594, 'logits/chosen': 3.017761707305908, 'logits/rejected': 3.6306841373443604, 'epoch': 0.02}
# {'loss': 0.685, 'grad_norm': 93.80490112304688, 'learning_rate': 3.45e-05, 'rewards/chosen': -0.2757147550582886, 'rewards/rejected': -0.4791845679283142, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.20346976816654205, 'logps/chosen': -518.7327880859375, 'logps/rejected': -409.4939270019531, 'logits/chosen': 3.5910720825195312, 'logits/rejected': 3.1186628341674805, 'epoch': 0.02}
# {'loss': 0.6243, 'grad_norm': 97.56023406982422, 'learning_rate': 3.5e-05, 'rewards/chosen': -0.425979346036911, 'rewards/rejected': -0.6513960361480713, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.22541669011116028, 'logps/chosen': -514.399169921875, 'logps/rejected': -460.2887268066406, 'logits/chosen': 2.7513039112091064, 'logits/rejected': 3.4147982597351074, 'epoch': 0.02}
# {'loss': 0.6098, 'grad_norm': 66.11347198486328, 'learning_rate': 3.55e-05, 'rewards/chosen': -0.11633449047803879, 'rewards/rejected': -0.4268019497394562, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.3104674220085144, 'logps/chosen': -397.9969177246094, 'logps/rejected': -346.7717590332031, 'logits/chosen': 2.9502174854278564, 'logits/rejected': 3.775559902191162, 'epoch': 0.02}
# {'loss': 0.6906, 'grad_norm': 87.92203521728516, 'learning_rate': 3.6e-05, 'rewards/chosen': -0.31367582082748413, 'rewards/rejected': -0.4404899477958679, 'rewards/accuracies': 0.625, 'rewards/margins': 0.12681417167186737, 'logps/chosen': -545.5176391601562, 'logps/rejected': -447.4228515625, 'logits/chosen': 3.8718819618225098, 'logits/rejected': 3.8385751247406006, 'epoch': 0.02}
# {'loss': 0.5714, 'grad_norm': 86.35733032226562, 'learning_rate': 3.65e-05, 'rewards/chosen': -0.4409315288066864, 'rewards/rejected': -0.8077372312545776, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.3668057322502136, 'logps/chosen': -617.201171875, 'logps/rejected': -464.5212097167969, 'logits/chosen': 3.352144241333008, 'logits/rejected': 2.798140525817871, 'epoch': 0.02}
# {'loss': 0.7426, 'grad_norm': 97.93633270263672, 'learning_rate': 3.7e-05, 'rewards/chosen': -0.5888229608535767, 'rewards/rejected': -0.6699440479278564, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.08112107217311859, 'logps/chosen': -517.3394775390625, 'logps/rejected': -346.50396728515625, 'logits/chosen': 1.894313097000122, 'logits/rejected': 1.676241159439087, 'epoch': 0.02}
# {'loss': 0.7033, 'grad_norm': 72.2210693359375, 'learning_rate': 3.7500000000000003e-05, 'rewards/chosen': -0.3047155439853668, 'rewards/rejected': -0.3727695345878601, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.06805399805307388, 'logps/chosen': -436.8930358886719, 'logps/rejected': -274.03839111328125, 'logits/chosen': 3.6116137504577637, 'logits/rejected': 2.620582103729248, 'epoch': 0.02}
# {'loss': 0.6064, 'grad_norm': 84.77555847167969, 'learning_rate': 3.8e-05, 'rewards/chosen': -0.32200634479522705, 'rewards/rejected': -0.6327664852142334, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.31076017022132874, 'logps/chosen': -590.8864135742188, 'logps/rejected': -579.5230712890625, 'logits/chosen': 2.4365553855895996, 'logits/rejected': 3.7418737411499023, 'epoch': 0.02}
# {'loss': 0.5778, 'grad_norm': 70.12779998779297, 'learning_rate': 3.85e-05, 'rewards/chosen': -0.19037321209907532, 'rewards/rejected': -0.5176944136619568, 'rewards/accuracies': 0.75, 'rewards/margins': 0.32732123136520386, 'logps/chosen': -476.9609680175781, 'logps/rejected': -443.750244140625, 'logits/chosen': 3.614147663116455, 'logits/rejected': 3.057119369506836, 'epoch': 0.02}
# {'loss': 0.5711, 'grad_norm': 67.63333129882812, 'learning_rate': 3.9000000000000006e-05, 'rewards/chosen': -0.28937965631484985, 'rewards/rejected': -0.6813378930091858, 'rewards/accuracies': 0.625, 'rewards/margins': 0.39195823669433594, 'logps/chosen': -591.3374633789062, 'logps/rejected': -388.48077392578125, 'logits/chosen': 4.327516555786133, 'logits/rejected': 2.6266725063323975, 'epoch': 0.02}
# {'loss': 0.5214, 'grad_norm': 70.83671569824219, 'learning_rate': 3.9500000000000005e-05, 'rewards/chosen': -0.2310921847820282, 'rewards/rejected': -0.6919333934783936, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.46084120869636536, 'logps/chosen': -504.40411376953125, 'logps/rejected': -479.2370910644531, 'logits/chosen': 3.7610325813293457, 'logits/rejected': 4.736295700073242, 'epoch': 0.02}
# {'loss': 0.719, 'grad_norm': 101.6651611328125, 'learning_rate': 4e-05, 'rewards/chosen': -0.5055289268493652, 'rewards/rejected': -0.5747309327125549, 'rewards/accuracies': 0.625, 'rewards/margins': 0.06920194625854492, 'logps/chosen': -543.9533081054688, 'logps/rejected': -615.1282958984375, 'logits/chosen': 2.585068464279175, 'logits/rejected': 3.112635850906372, 'epoch': 0.02}
# {'loss': 0.842, 'grad_norm': 103.11865234375, 'learning_rate': 4.05e-05, 'rewards/chosen': -0.6711083054542542, 'rewards/rejected': -0.5452206134796143, 'rewards/accuracies': 0.5, 'rewards/margins': -0.12588773667812347, 'logps/chosen': -471.712158203125, 'logps/rejected': -554.1220092773438, 'logits/chosen': 1.7773923873901367, 'logits/rejected': 2.378953456878662, 'epoch': 0.02}
# {'loss': 0.7268, 'grad_norm': 81.70553588867188, 'learning_rate': 4.1e-05, 'rewards/chosen': -0.5246980786323547, 'rewards/rejected': -0.5691558122634888, 'rewards/accuracies': 0.375, 'rewards/margins': 0.044457726180553436, 'logps/chosen': -277.7543029785156, 'logps/rejected': -316.4972839355469, 'logits/chosen': 3.5313363075256348, 'logits/rejected': 3.1229257583618164, 'epoch': 0.02}
# {'loss': 0.942, 'grad_norm': 108.43360900878906, 'learning_rate': 4.15e-05, 'rewards/chosen': -0.7258118391036987, 'rewards/rejected': -0.6410125494003296, 'rewards/accuracies': 0.625, 'rewards/margins': -0.08479927480220795, 'logps/chosen': -467.9803771972656, 'logps/rejected': -363.1566162109375, 'logits/chosen': 2.325775384902954, 'logits/rejected': 2.427157163619995, 'epoch': 0.02}
# {'loss': 0.7622, 'grad_norm': 98.56800079345703, 'learning_rate': 4.2e-05, 'rewards/chosen': -0.520329475402832, 'rewards/rejected': -0.5403156280517578, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.019986115396022797, 'logps/chosen': -437.3880310058594, 'logps/rejected': -481.41839599609375, 'logits/chosen': 2.7318334579467773, 'logits/rejected': 2.8472163677215576, 'epoch': 0.02}
# {'loss': 0.643, 'grad_norm': 77.93053436279297, 'learning_rate': 4.25e-05, 'rewards/chosen': -0.45473670959472656, 'rewards/rejected': -0.6310149431228638, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.17627820372581482, 'logps/chosen': -484.187744140625, 'logps/rejected': -350.7308349609375, 'logits/chosen': 2.703547239303589, 'logits/rejected': 3.5676321983337402, 'epoch': 0.02}
# {'loss': 0.7156, 'grad_norm': 82.18643951416016, 'learning_rate': 4.3e-05, 'rewards/chosen': -0.636419415473938, 'rewards/rejected': -0.788506269454956, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.1520867943763733, 'logps/chosen': -333.6039123535156, 'logps/rejected': -340.1128234863281, 'logits/chosen': 2.5025362968444824, 'logits/rejected': 3.314084529876709, 'epoch': 0.02}
# {'loss': 0.4921, 'grad_norm': 53.0712890625, 'learning_rate': 4.35e-05, 'rewards/chosen': -0.39554017782211304, 'rewards/rejected': -1.0564329624176025, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.6608927249908447, 'logps/chosen': -273.36273193359375, 'logps/rejected': -371.0162353515625, 'logits/chosen': 2.492527484893799, 'logits/rejected': 3.2580459117889404, 'epoch': 0.02}
# {'loss': 0.7042, 'grad_norm': 80.1554946899414, 'learning_rate': 4.4000000000000006e-05, 'rewards/chosen': -0.4616849422454834, 'rewards/rejected': -0.5134584903717041, 'rewards/accuracies': 0.5, 'rewards/margins': 0.05177360400557518, 'logps/chosen': -439.1780700683594, 'logps/rejected': -323.62060546875, 'logits/chosen': 3.3758692741394043, 'logits/rejected': 4.234143257141113, 'epoch': 0.02}
# {'loss': 0.7151, 'grad_norm': 81.26270294189453, 'learning_rate': 4.4500000000000004e-05, 'rewards/chosen': -0.6458727717399597, 'rewards/rejected': -0.8786285519599915, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.23275579512119293, 'logps/chosen': -493.38409423828125, 'logps/rejected': -398.06707763671875, 'logits/chosen': 2.195441246032715, 'logits/rejected': 3.126840591430664, 'epoch': 0.02}
# {'loss': 0.688, 'grad_norm': 72.02772521972656, 'learning_rate': 4.5e-05, 'rewards/chosen': -0.6307075023651123, 'rewards/rejected': -0.8267257213592529, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.19601817429065704, 'logps/chosen': -513.1768798828125, 'logps/rejected': -344.7911376953125, 'logits/chosen': 2.1372969150543213, 'logits/rejected': 1.8796963691711426, 'epoch': 0.02}
# {'loss': 0.6874, 'grad_norm': 85.96553802490234, 'learning_rate': 4.55e-05, 'rewards/chosen': -0.5017597675323486, 'rewards/rejected': -0.6111479997634888, 'rewards/accuracies': 0.625, 'rewards/margins': 0.10938828438520432, 'logps/chosen': -428.0765686035156, 'logps/rejected': -384.53826904296875, 'logits/chosen': 3.5439491271972656, 'logits/rejected': 3.8448538780212402, 'epoch': 0.02}
# {'loss': 0.6466, 'grad_norm': 82.87813568115234, 'learning_rate': 4.600000000000001e-05, 'rewards/chosen': -0.6435645818710327, 'rewards/rejected': -0.9123907089233398, 'rewards/accuracies': 0.75, 'rewards/margins': 0.26882606744766235, 'logps/chosen': -628.2797241210938, 'logps/rejected': -414.7825927734375, 'logits/chosen': 2.7710041999816895, 'logits/rejected': 2.4094035625457764, 'epoch': 0.02}
# {'loss': 0.5693, 'grad_norm': 58.943153381347656, 'learning_rate': 4.6500000000000005e-05, 'rewards/chosen': -0.3339352607727051, 'rewards/rejected': -0.6869364976882935, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.353001207113266, 'logps/chosen': -382.7840576171875, 'logps/rejected': -314.128173828125, 'logits/chosen': 4.3022332191467285, 'logits/rejected': 3.1711559295654297, 'epoch': 0.02}
# {'loss': 0.7072, 'grad_norm': 81.2945327758789, 'learning_rate': 4.7e-05, 'rewards/chosen': -0.6095759272575378, 'rewards/rejected': -0.7874892950057983, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.1779133677482605, 'logps/chosen': -396.9088134765625, 'logps/rejected': -373.69873046875, 'logits/chosen': 3.701667308807373, 'logits/rejected': 4.1045379638671875, 'epoch': 0.02}
# {'loss': 0.4999, 'grad_norm': 72.36111450195312, 'learning_rate': 4.75e-05, 'rewards/chosen': -0.42838054895401, 'rewards/rejected': -0.9785520434379578, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5501714944839478, 'logps/chosen': -486.9364013671875, 'logps/rejected': -370.2143859863281, 'logits/chosen': 2.360872507095337, 'logits/rejected': 2.6246755123138428, 'epoch': 0.02}
# {'loss': 0.569, 'grad_norm': 85.24842834472656, 'learning_rate': 4.8e-05, 'rewards/chosen': -0.5098025798797607, 'rewards/rejected': -1.0814261436462402, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.571623682975769, 'logps/chosen': -459.109130859375, 'logps/rejected': -576.993408203125, 'logits/chosen': 3.2808432579040527, 'logits/rejected': 3.58600115776062, 'epoch': 0.02}
# {'loss': 0.7348, 'grad_norm': 67.15052032470703, 'learning_rate': 4.85e-05, 'rewards/chosen': -0.6194210052490234, 'rewards/rejected': -0.6376204490661621, 'rewards/accuracies': 0.5, 'rewards/margins': 0.018199443817138672, 'logps/chosen': -380.73272705078125, 'logps/rejected': -252.60061645507812, 'logits/chosen': 3.1708619594573975, 'logits/rejected': 3.444620132446289, 'epoch': 0.02}
# {'loss': 0.4976, 'grad_norm': 61.09354782104492, 'learning_rate': 4.9e-05, 'rewards/chosen': -0.2816489040851593, 'rewards/rejected': -0.8225624561309814, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5409135818481445, 'logps/chosen': -431.1700744628906, 'logps/rejected': -267.6109619140625, 'logits/chosen': 2.2636091709136963, 'logits/rejected': 3.4521496295928955, 'epoch': 0.03}
# {'loss': 0.6122, 'grad_norm': 84.56346893310547, 'learning_rate': 4.9500000000000004e-05, 'rewards/chosen': -0.4273420572280884, 'rewards/rejected': -0.9237735867500305, 'rewards/accuracies': 0.625, 'rewards/margins': 0.49643152952194214, 'logps/chosen': -667.0291748046875, 'logps/rejected': -704.374267578125, 'logits/chosen': 2.813687324523926, 'logits/rejected': 3.767487049102783, 'epoch': 0.03}
# {'loss': 0.6105, 'grad_norm': 66.59628295898438, 'learning_rate': 5e-05, 'rewards/chosen': -0.5387160778045654, 'rewards/rejected': -0.813231348991394, 'rewards/accuracies': 0.625, 'rewards/margins': 0.2745152711868286, 'logps/chosen': -329.9827575683594, 'logps/rejected': -235.91966247558594, 'logits/chosen': 2.6387577056884766, 'logits/rejected': 1.5707935094833374, 'epoch': 0.03}
# {'loss': 0.5699, 'grad_norm': 66.73095703125, 'learning_rate': 4.998766400914329e-05, 'rewards/chosen': -0.6576467752456665, 'rewards/rejected': -1.011892318725586, 'rewards/accuracies': 0.75, 'rewards/margins': 0.3542454242706299, 'logps/chosen': -450.2084655761719, 'logps/rejected': -373.78680419921875, 'logits/chosen': 3.0988500118255615, 'logits/rejected': 3.6263415813446045, 'epoch': 0.03}
# {'loss': 0.7924, 'grad_norm': 95.5784912109375, 'learning_rate': 4.995066821070679e-05, 'rewards/chosen': -1.03654146194458, 'rewards/rejected': -1.0671257972717285, 'rewards/accuracies': 0.5, 'rewards/margins': 0.030584335327148438, 'logps/chosen': -635.5745849609375, 'logps/rejected': -524.6180419921875, 'logits/chosen': 3.1729531288146973, 'logits/rejected': 3.528245210647583, 'epoch': 0.03}
# {'loss': 0.397, 'grad_norm': 53.603206634521484, 'learning_rate': 4.9889049115077005e-05, 'rewards/chosen': -0.3437623381614685, 'rewards/rejected': -1.2656011581420898, 'rewards/accuracies': 0.875, 'rewards/margins': 0.9218388795852661, 'logps/chosen': -525.1087036132812, 'logps/rejected': -437.9944763183594, 'logits/chosen': 2.652438163757324, 'logits/rejected': 2.8888065814971924, 'epoch': 0.03}
# {'loss': 0.7304, 'grad_norm': 82.3192367553711, 'learning_rate': 4.980286753286195e-05, 'rewards/chosen': -0.5123260617256165, 'rewards/rejected': -0.5319219827651978, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.019595950841903687, 'logps/chosen': -454.8577575683594, 'logps/rejected': -318.76702880859375, 'logits/chosen': 1.9149662256240845, 'logits/rejected': 2.7348217964172363, 'epoch': 0.03}
# {'loss': 0.76, 'grad_norm': 79.60240173339844, 'learning_rate': 4.9692208514878444e-05, 'rewards/chosen': -0.9663441181182861, 'rewards/rejected': -0.9633221626281738, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.0030219033360481262, 'logps/chosen': -334.8752746582031, 'logps/rejected': -274.8498229980469, 'logits/chosen': 4.5742387771606445, 'logits/rejected': 3.0591514110565186, 'epoch': 0.03}
# {'loss': 0.6591, 'grad_norm': 81.5180892944336, 'learning_rate': 4.9557181268217227e-05, 'rewards/chosen': -0.5488086342811584, 'rewards/rejected': -0.8611435890197754, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.31233492493629456, 'logps/chosen': -466.42388916015625, 'logps/rejected': -321.4561462402344, 'logits/chosen': 2.730005979537964, 'logits/rejected': 3.273266553878784, 'epoch': 0.03}
# {'loss': 0.5141, 'grad_norm': 61.57428741455078, 'learning_rate': 4.939791904846869e-05, 'rewards/chosen': -0.3287028670310974, 'rewards/rejected': -1.1709814071655273, 'rewards/accuracies': 0.75, 'rewards/margins': 0.8422785401344299, 'logps/chosen': -354.2879333496094, 'logps/rejected': -395.3304443359375, 'logits/chosen': 3.9234840869903564, 'logits/rejected': 3.40995192527771, 'epoch': 0.03}
# {'loss': 0.608, 'grad_norm': 86.50187683105469, 'learning_rate': 4.9214579028215776e-05, 'rewards/chosen': -1.02481210231781, 'rewards/rejected': -1.343990445137024, 'rewards/accuracies': 0.75, 'rewards/margins': 0.31917843222618103, 'logps/chosen': -564.2868041992188, 'logps/rejected': -433.6468811035156, 'logits/chosen': 2.5290870666503906, 'logits/rejected': 2.5485222339630127, 'epoch': 0.03}
# {'loss': 0.6402, 'grad_norm': 77.52259826660156, 'learning_rate': 4.900734214192358e-05, 'rewards/chosen': -0.6568476557731628, 'rewards/rejected': -1.0997287034988403, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.44288110733032227, 'logps/chosen': -385.26177978515625, 'logps/rejected': -381.4964294433594, 'logits/chosen': 2.071913003921509, 'logits/rejected': 2.386665105819702, 'epoch': 0.03}
# {'loss': 0.5966, 'grad_norm': 71.41263580322266, 'learning_rate': 4.877641290737884e-05, 'rewards/chosen': -0.7265567183494568, 'rewards/rejected': -1.1833115816116333, 'rewards/accuracies': 0.75, 'rewards/margins': 0.45675480365753174, 'logps/chosen': -468.9163818359375, 'logps/rejected': -463.5421142578125, 'logits/chosen': 1.6499543190002441, 'logits/rejected': 2.4338059425354004, 'epoch': 0.03}
# {'loss': 0.6577, 'grad_norm': 98.24583435058594, 'learning_rate': 4.852201922385564e-05, 'rewards/chosen': -0.5752169489860535, 'rewards/rejected': -1.062282919883728, 'rewards/accuracies': 0.625, 'rewards/margins': 0.48706597089767456, 'logps/chosen': -554.6060791015625, 'logps/rejected': -437.6263427734375, 'logits/chosen': 2.795368194580078, 'logits/rejected': 2.418917417526245, 'epoch': 0.03}
# {'loss': 0.7045, 'grad_norm': 77.40742492675781, 'learning_rate': 4.8244412147206284e-05, 'rewards/chosen': -0.716003954410553, 'rewards/rejected': -0.9729276895523071, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.25692376494407654, 'logps/chosen': -485.6568603515625, 'logps/rejected': -403.43212890625, 'logits/chosen': 2.2272770404815674, 'logits/rejected': 2.438516139984131, 'epoch': 0.03}
# {'loss': 0.5983, 'grad_norm': 90.90229797363281, 'learning_rate': 4.794386564209953e-05, 'rewards/chosen': -0.9935909509658813, 'rewards/rejected': -1.3430371284484863, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.34944599866867065, 'logps/chosen': -337.31610107421875, 'logps/rejected': -314.8204650878906, 'logits/chosen': 2.066253662109375, 'logits/rejected': 2.17972993850708, 'epoch': 0.03}
# {'loss': 0.6891, 'grad_norm': 86.54534912109375, 'learning_rate': 4.762067631165049e-05, 'rewards/chosen': -0.9873117804527283, 'rewards/rejected': -1.5400567054748535, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.5527451038360596, 'logps/chosen': -598.4756469726562, 'logps/rejected': -585.4625244140625, 'logits/chosen': 2.225287914276123, 'logits/rejected': 1.7572495937347412, 'epoch': 0.03}
# {'loss': 0.6097, 'grad_norm': 70.9275131225586, 'learning_rate': 4.72751631047092e-05, 'rewards/chosen': -0.9417693614959717, 'rewards/rejected': -1.374706506729126, 'rewards/accuracies': 0.75, 'rewards/margins': 0.4329371452331543, 'logps/chosen': -419.9421081542969, 'logps/rejected': -368.99127197265625, 'logits/chosen': 3.6760902404785156, 'logits/rejected': 3.024862051010132, 'epoch': 0.03}
# {'loss': 0.6853, 'grad_norm': 89.330078125, 'learning_rate': 4.690766700109659e-05, 'rewards/chosen': -0.8333787322044373, 'rewards/rejected': -1.1379761695861816, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.3045973479747772, 'logps/chosen': -462.3473815917969, 'logps/rejected': -460.83087158203125, 'logits/chosen': 2.9300684928894043, 'logits/rejected': 3.4294424057006836, 'epoch': 0.03}
# {'loss': 0.6069, 'grad_norm': 82.99807739257812, 'learning_rate': 4.65185506750986e-05, 'rewards/chosen': -0.8816158175468445, 'rewards/rejected': -1.1313066482543945, 'rewards/accuracies': 0.75, 'rewards/margins': 0.24969081580638885, 'logps/chosen': -434.3683166503906, 'logps/rejected': -416.3007507324219, 'logits/chosen': 1.0978583097457886, 'logits/rejected': 0.9482104778289795, 'epoch': 0.03}
# {'loss': 0.5508, 'grad_norm': 61.43997573852539, 'learning_rate': 4.610819813755038e-05, 'rewards/chosen': -0.958163321018219, 'rewards/rejected': -1.5077232122421265, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5495598912239075, 'logps/chosen': -273.39105224609375, 'logps/rejected': -305.6917724609375, 'logits/chosen': 3.1158671379089355, 'logits/rejected': 3.04404616355896, 'epoch': 0.03}
# {'loss': 0.7451, 'grad_norm': 124.57633209228516, 'learning_rate': 4.567701435686404e-05, 'rewards/chosen': -1.3152058124542236, 'rewards/rejected': -1.5321398973464966, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2169341742992401, 'logps/chosen': -687.9251708984375, 'logps/rejected': -557.1256103515625, 'logits/chosen': 3.590829849243164, 'logits/rejected': 2.5700697898864746, 'epoch': 0.03}
# {'loss': 0.8719, 'grad_norm': 114.04688262939453, 'learning_rate': 4.522542485937369e-05, 'rewards/chosen': -1.4615702629089355, 'rewards/rejected': -1.46604585647583, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.004475511610507965, 'logps/chosen': -683.493896484375, 'logps/rejected': -454.0982971191406, 'logits/chosen': 2.1902642250061035, 'logits/rejected': 2.407693386077881, 'epoch': 0.03}
# ...
# {'loss': 0.9677, 'grad_norm': 112.7752914428711, 'learning_rate': 1.5071302734130489e-05, 'rewards/chosen': -1.542183756828308, 'rewards/rejected': -1.3677189350128174, 'rewards/accuracies': 0.25, 'rewards/margins': -0.17446479201316833, 'logps/chosen': -536.8624267578125, 'logps/rejected': -575.39013671875, 'logits/chosen': 3.305631160736084, 'logits/rejected': 3.047154664993286, 'epoch': 0.04}
# {'loss': 0.5818, 'grad_norm': 81.2853775024414, 'learning_rate': 1.4355517710873184e-05, 'rewards/chosen': -1.0697578191757202, 'rewards/rejected': -1.7223939895629883, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6526360511779785, 'logps/chosen': -574.3815307617188, 'logps/rejected': -486.541748046875, 'logits/chosen': 1.9394748210906982, 'logits/rejected': 1.8022816181182861, 'epoch': 0.04}
# {'loss': 0.4918, 'grad_norm': 56.98745346069336, 'learning_rate': 1.3650237506511331e-05, 'rewards/chosen': -0.5990197062492371, 'rewards/rejected': -1.293989896774292, 'rewards/accuracies': 0.875, 'rewards/margins': 0.6949701309204102, 'logps/chosen': -289.37030029296875, 'logps/rejected': -371.4733581542969, 'logits/chosen': 4.9942216873168945, 'logits/rejected': 3.5881524085998535, 'epoch': 0.04}
# {'loss': 0.6444, 'grad_norm': 92.48770904541016, 'learning_rate': 1.2956158147457115e-05, 'rewards/chosen': -1.2466297149658203, 'rewards/rejected': -1.5901130437850952, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.3434833586215973, 'logps/chosen': -625.6795654296875, 'logps/rejected': -608.9915771484375, 'logits/chosen': 3.658665657043457, 'logits/rejected': 3.555752754211426, 'epoch': 0.04}
# {'loss': 0.8515, 'grad_norm': 101.99283599853516, 'learning_rate': 1.2273964606240718e-05, 'rewards/chosen': -1.6867022514343262, 'rewards/rejected': -1.5768380165100098, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.10986412316560745, 'logps/chosen': -475.0804443359375, 'logps/rejected': -440.577392578125, 'logits/chosen': 2.138230562210083, 'logits/rejected': 3.0997166633605957, 'epoch': 0.04}
# {'loss': 0.6911, 'grad_norm': 95.40152740478516, 'learning_rate': 1.1604330125525079e-05, 'rewards/chosen': -0.8598344922065735, 'rewards/rejected': -1.118148684501648, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.25831419229507446, 'logps/chosen': -446.2906494140625, 'logps/rejected': -409.7793273925781, 'logits/chosen': 2.7321619987487793, 'logits/rejected': 3.3858728408813477, 'epoch': 0.04}
# {'loss': 0.9755, 'grad_norm': 100.18212127685547, 'learning_rate': 1.0947915553696742e-05, 'rewards/chosen': -1.451821208000183, 'rewards/rejected': -1.1841158866882324, 'rewards/accuracies': 0.375, 'rewards/margins': -0.26770538091659546, 'logps/chosen': -420.4041748046875, 'logps/rejected': -357.5068359375, 'logits/chosen': 4.164671897888184, 'logits/rejected': 3.003413438796997, 'epoch': 0.04}
# {'loss': 0.4749, 'grad_norm': 65.74530029296875, 'learning_rate': 1.0305368692688174e-05, 'rewards/chosen': -0.9902684688568115, 'rewards/rejected': -2.0057270526885986, 'rewards/accuracies': 0.75, 'rewards/margins': 1.015458583831787, 'logps/chosen': -306.339111328125, 'logps/rejected': -428.11492919921875, 'logits/chosen': 3.2999062538146973, 'logits/rejected': 4.295263767242432, 'epoch': 0.04}
# {'loss': 0.5172, 'grad_norm': 68.94242095947266, 'learning_rate': 9.677323658675594e-06, 'rewards/chosen': -0.8746483325958252, 'rewards/rejected': -1.4717614650726318, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5971131324768066, 'logps/chosen': -537.440185546875, 'logps/rejected': -470.8414611816406, 'logits/chosen': 3.068913459777832, 'logits/rejected': 2.5092546939849854, 'epoch': 0.04}
# {'loss': 0.8966, 'grad_norm': 108.54750061035156, 'learning_rate': 9.064400256282757e-06, 'rewards/chosen': -1.000740647315979, 'rewards/rejected': -0.9410731792449951, 'rewards/accuracies': 0.625, 'rewards/margins': -0.05966752767562866, 'logps/chosen': -311.90179443359375, 'logps/rejected': -385.73834228515625, 'logits/chosen': 2.7843575477600098, 'logits/rejected': 4.091908931732178, 'epoch': 0.04}
# {'loss': 0.7699, 'grad_norm': 88.69291687011719, 'learning_rate': 8.467203366908707e-06, 'rewards/chosen': -1.2070380449295044, 'rewards/rejected': -1.4905524253845215, 'rewards/accuracies': 0.625, 'rewards/margins': 0.28351426124572754, 'logps/chosen': -513.811767578125, 'logps/rejected': -423.8024597167969, 'logits/chosen': 4.635036945343018, 'logits/rejected': 4.4316606521606445, 'epoch': 0.04}
# {'loss': 0.724, 'grad_norm': 74.82841491699219, 'learning_rate': 7.886322351782783e-06, 'rewards/chosen': -0.9981694221496582, 'rewards/rejected': -1.3050787448883057, 'rewards/accuracies': 0.625, 'rewards/margins': 0.3069092631340027, 'logps/chosen': -385.234619140625, 'logps/rejected': -371.3030700683594, 'logits/chosen': 2.4488930702209473, 'logits/rejected': 1.2245213985443115, 'epoch': 0.04}
# {'loss': 0.7496, 'grad_norm': 86.68800354003906, 'learning_rate': 7.3223304703363135e-06, 'rewards/chosen': -1.4162532091140747, 'rewards/rejected': -1.5707722902297974, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1545192301273346, 'logps/chosen': -292.26055908203125, 'logps/rejected': -275.4461364746094, 'logits/chosen': 3.640686511993408, 'logits/rejected': 3.4978997707366943, 'epoch': 0.05}
# {'loss': 0.5222, 'grad_norm': 58.58742141723633, 'learning_rate': 6.775784314464717e-06, 'rewards/chosen': -0.8752983808517456, 'rewards/rejected': -1.4085477590560913, 'rewards/accuracies': 0.75, 'rewards/margins': 0.5332493185997009, 'logps/chosen': -340.4321594238281, 'logps/rejected': -285.0037841796875, 'logits/chosen': 3.702296018600464, 'logits/rejected': 3.796337127685547, 'epoch': 0.05}
# {'loss': 0.6978, 'grad_norm': 104.40570068359375, 'learning_rate': 6.247223259238511e-06, 'rewards/chosen': -0.959701418876648, 'rewards/rejected': -1.5283228158950806, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.5686213374137878, 'logps/chosen': -496.07452392578125, 'logps/rejected': -472.9796142578125, 'logits/chosen': 1.5319510698318481, 'logits/rejected': 1.70345938205719, 'epoch': 0.05}
# {'loss': 0.3531, 'grad_norm': 54.79384231567383, 'learning_rate': 5.737168930605272e-06, 'rewards/chosen': -0.5455811619758606, 'rewards/rejected': -1.9010767936706543, 'rewards/accuracies': 0.75, 'rewards/margins': 1.355495572090149, 'logps/chosen': -440.4465026855469, 'logps/rejected': -663.986328125, 'logits/chosen': 3.4169349670410156, 'logits/rejected': 3.7788100242614746, 'epoch': 0.05}
# {'loss': 0.7986, 'grad_norm': 115.00716400146484, 'learning_rate': 5.24612469060774e-06, 'rewards/chosen': -0.9837775826454163, 'rewards/rejected': -1.1030843257904053, 'rewards/accuracies': 0.5, 'rewards/margins': 0.11930672079324722, 'logps/chosen': -342.30523681640625, 'logps/rejected': -242.53668212890625, 'logits/chosen': 4.780608177185059, 'logits/rejected': 4.409432411193848, 'epoch': 0.05}
# {'loss': 0.5439, 'grad_norm': 59.34993362426758, 'learning_rate': 4.7745751406263165e-06, 'rewards/chosen': -1.0388436317443848, 'rewards/rejected': -1.6948182582855225, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.6559746265411377, 'logps/chosen': -450.862548828125, 'logps/rejected': -280.9174499511719, 'logits/chosen': 3.5120420455932617, 'logits/rejected': 2.69305682182312, 'epoch': 0.05}
# {'loss': 0.4817, 'grad_norm': 64.88966369628906, 'learning_rate': 4.322985643135952e-06, 'rewards/chosen': -0.8862853646278381, 'rewards/rejected': -1.6826143264770508, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.7963290214538574, 'logps/chosen': -596.6010131835938, 'logps/rejected': -450.36883544921875, 'logits/chosen': 3.7904160022735596, 'logits/rejected': 3.528806686401367, 'epoch': 0.05}
# {'loss': 0.5757, 'grad_norm': 53.878963470458984, 'learning_rate': 3.891801862449629e-06, 'rewards/chosen': -0.8785402178764343, 'rewards/rejected': -1.4494025707244873, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5708624720573425, 'logps/chosen': -337.244873046875, 'logps/rejected': -286.1331481933594, 'logits/chosen': 4.021664142608643, 'logits/rejected': 3.925992965698242, 'epoch': 0.05}
# {'loss': 0.6049, 'grad_norm': 82.02711486816406, 'learning_rate': 3.4814493249014116e-06, 'rewards/chosen': -1.146823763847351, 'rewards/rejected': -1.5146820545196533, 'rewards/accuracies': 0.625, 'rewards/margins': 0.3678583800792694, 'logps/chosen': -518.7557373046875, 'logps/rejected': -359.430419921875, 'logits/chosen': 3.0174384117126465, 'logits/rejected': 2.9165196418762207, 'epoch': 0.05}
# {'loss': 0.8584, 'grad_norm': 107.11343383789062, 'learning_rate': 3.092332998903416e-06, 'rewards/chosen': -1.3108981847763062, 'rewards/rejected': -1.4115370512008667, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.10063883662223816, 'logps/chosen': -429.5868225097656, 'logps/rejected': -439.74273681640625, 'logits/chosen': 3.4868195056915283, 'logits/rejected': 4.111245632171631, 'epoch': 0.05}
# {'loss': 0.5563, 'grad_norm': 66.78609466552734, 'learning_rate': 2.7248368952908053e-06, 'rewards/chosen': -0.783129870891571, 'rewards/rejected': -1.4250142574310303, 'rewards/accuracies': 0.625, 'rewards/margins': 0.641884446144104, 'logps/chosen': -338.77667236328125, 'logps/rejected': -441.0667419433594, 'logits/chosen': 2.488023281097412, 'logits/rejected': 3.2244386672973633, 'epoch': 0.05}
# {'loss': 0.5742, 'grad_norm': 62.120235443115234, 'learning_rate': 2.379323688349516e-06, 'rewards/chosen': -1.0802717208862305, 'rewards/rejected': -1.653763771057129, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.573492169380188, 'logps/chosen': -458.6126708984375, 'logps/rejected': -443.1781005859375, 'logits/chosen': 3.7359442710876465, 'logits/rejected': 4.141632080078125, 'epoch': 0.05}
# {'loss': 0.7626, 'grad_norm': 76.08590698242188, 'learning_rate': 2.0561343579004715e-06, 'rewards/chosen': -1.1459630727767944, 'rewards/rejected': -1.39644455909729, 'rewards/accuracies': 0.5, 'rewards/margins': 0.2504815459251404, 'logps/chosen': -385.63592529296875, 'logps/rejected': -335.3365173339844, 'logits/chosen': 3.40274977684021, 'logits/rejected': 3.1945598125457764, 'epoch': 0.05}
# {'loss': 0.5259, 'grad_norm': 62.06913757324219, 'learning_rate': 1.7555878527937164e-06, 'rewards/chosen': -0.7289863228797913, 'rewards/rejected': -1.3572601079940796, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.6282736659049988, 'logps/chosen': -288.6947326660156, 'logps/rejected': -349.29351806640625, 'logits/chosen': 2.7754833698272705, 'logits/rejected': 2.8614630699157715, 'epoch': 0.05}
# {'loss': 0.7441, 'grad_norm': 85.28390502929688, 'learning_rate': 1.4779807761443636e-06, 'rewards/chosen': -1.162440538406372, 'rewards/rejected': -1.2936086654663086, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1311682164669037, 'logps/chosen': -420.15478515625, 'logps/rejected': -461.2704162597656, 'logits/chosen': 1.1093428134918213, 'logits/rejected': 2.8539414405822754, 'epoch': 0.05}
# {'loss': 0.5462, 'grad_norm': 73.6417465209961, 'learning_rate': 1.2235870926211619e-06, 'rewards/chosen': -0.7643475532531738, 'rewards/rejected': -1.2156586647033691, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.4513111412525177, 'logps/chosen': -368.3407897949219, 'logps/rejected': -379.9474792480469, 'logits/chosen': 2.766054630279541, 'logits/rejected': 2.2207515239715576, 'epoch': 0.05}
# {'loss': 0.7641, 'grad_norm': 86.37100219726562, 'learning_rate': 9.926578580764234e-07, 'rewards/chosen': -1.218764066696167, 'rewards/rejected': -1.3562084436416626, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.1374443620443344, 'logps/chosen': -398.16009521484375, 'logps/rejected': -356.6059875488281, 'logits/chosen': 3.5045902729034424, 'logits/rejected': 4.046146392822266, 'epoch': 0.05}
# {'loss': 0.6763, 'grad_norm': 73.44856262207031, 'learning_rate': 7.854209717842231e-07, 'rewards/chosen': -0.8360064625740051, 'rewards/rejected': -1.309184193611145, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.4731777608394623, 'logps/chosen': -320.37310791015625, 'logps/rejected': -317.9700622558594, 'logits/chosen': 2.85439395904541, 'logits/rejected': 2.300097703933716, 'epoch': 0.05}
# {'loss': 0.6681, 'grad_norm': 79.75537872314453, 'learning_rate': 6.020809515313142e-07, 'rewards/chosen': -1.1490908861160278, 'rewards/rejected': -1.3709402084350586, 'rewards/accuracies': 0.5, 'rewards/margins': 0.22184932231903076, 'logps/chosen': -428.34271240234375, 'logps/rejected': -337.68011474609375, 'logits/chosen': 2.5939791202545166, 'logits/rejected': 2.572183132171631, 'epoch': 0.05}
# {'loss': 0.6584, 'grad_norm': 77.2697982788086, 'learning_rate': 4.4281873178278475e-07, 'rewards/chosen': -1.31334388256073, 'rewards/rejected': -1.5548831224441528, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.24153929948806763, 'logps/chosen': -544.295166015625, 'logps/rejected': -410.2479248046875, 'logits/chosen': 2.432389259338379, 'logits/rejected': 1.605338454246521, 'epoch': 0.05}
# {'loss': 0.6567, 'grad_norm': 67.55132293701172, 'learning_rate': 3.077914851215585e-07, 'rewards/chosen': -1.041372299194336, 'rewards/rejected': -1.4733104705810547, 'rewards/accuracies': 0.75, 'rewards/margins': 0.43193793296813965, 'logps/chosen': -327.87286376953125, 'logps/rejected': -307.0361633300781, 'logits/chosen': 3.7577199935913086, 'logits/rejected': 3.4830994606018066, 'epoch': 0.05}
# {'loss': 0.7216, 'grad_norm': 92.42791748046875, 'learning_rate': 1.9713246713805588e-07, 'rewards/chosen': -1.2413464784622192, 'rewards/rejected': -1.4693117141723633, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.2279653698205948, 'logps/chosen': -468.5346984863281, 'logps/rejected': -523.9479370117188, 'logits/chosen': 1.9099012613296509, 'logits/rejected': 2.6094117164611816, 'epoch': 0.05}
# {'loss': 0.8185, 'grad_norm': 95.37403106689453, 'learning_rate': 1.109508849230001e-07, 'rewards/chosen': -1.5349195003509521, 'rewards/rejected': -1.577444076538086, 'rewards/accuracies': 0.5, 'rewards/margins': 0.04252452403306961, 'logps/chosen': -442.404296875, 'logps/rejected': -359.4892883300781, 'logits/chosen': 2.702040195465088, 'logits/rejected': 3.4792513847351074, 'epoch': 0.05}
# {'loss': 0.7077, 'grad_norm': 70.51473999023438, 'learning_rate': 4.9331789293211026e-08, 'rewards/chosen': -0.8861865401268005, 'rewards/rejected': -1.0718835592269897, 'rewards/accuracies': 0.75, 'rewards/margins': 0.18569697439670563, 'logps/chosen': -311.87786865234375, 'logps/rejected': -344.78857421875, 'logits/chosen': 2.277756690979004, 'logits/rejected': 2.3639163970947266, 'epoch': 0.05}
# {'loss': 0.783, 'grad_norm': 79.35419464111328, 'learning_rate': 1.233599085671e-08, 'rewards/chosen': -1.0694468021392822, 'rewards/rejected': -1.199582815170288, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.1301361471414566, 'logps/chosen': -342.588623046875, 'logps/rejected': -210.7822265625, 'logits/chosen': 3.361302375793457, 'logits/rejected': 2.393533229827881, 'epoch': 0.05}
# {'loss': 0.7409, 'grad_norm': 81.16616821289062, 'learning_rate': 0.0, 'rewards/chosen': -1.3762133121490479, 'rewards/rejected': -1.4115246534347534, 'rewards/accuracies': 0.5, 'rewards/margins': 0.035311270505189896, 'logps/chosen': -315.9568176269531, 'logps/rejected': -442.72540283203125, 'logits/chosen': 3.902482509613037, 'logits/rejected': 4.22369384765625, 'epoch': 0.05}
# {'train_runtime': 212.9573, 'train_samples_per_second': 15.026, 'train_steps_per_second': 0.939, 'train_loss': 0.6647968944907189, 'epoch': 0.05}
# TrainOutput(global_step=200, training_loss=0.6647968944907189, metrics={'train_runtime': 212.9573, 'train_samples_per_second': 15.026, 'train_steps_per_second': 0.939, 'total_flos': 0.0, 'train_loss': 0.6647968944907189, 'epoch': 0.05149993562508047})

# %%
# Save the model
trainer.save_model(f"./{finetune_name}")

# %%
# Save to the huggingface hub if login (HF_TOKEN is set) ... NOPE!
if os.getenv("HF_TOKEN") and False:
    trainer.push_to_hub(tags=finetune_tags)

# %% [markdown]
# ## 💐 You're done!
#
# This notebook provided a step-by-step guide to fine-tuning the `HuggingFaceTB/SmolLM2-135M` model using the `DPOTrainer`. By following these steps, you can adapt the model to perform specific tasks more effectively. If you want to carry on working on this course, here are steps you could try out:
#
# - Try this notebook on a harder difficulty
# - Review a colleagues PR
# - Improve the course material via an Issue or PR.
